# %%
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages
    )
    return message.content[0].text

# %%
messages = []

while True:
    # get user input
    user_input = input("> ")
    print(">", user_input)

    # add user input to list of messages
    add_user_message(messages, user_input)
    
    # call claude with chat function
    response = chat(messages)
    print(response)
    
    # add generated text to list of messages
    add_assistant_message(messages, response)
    
    # print messages
    print(messages)
# Out:
# >  what is 2+2?
# > what is 2+2?
# 2 + 2 = **4**
# [{'role': 'user', 'content': 'what is 2+2?'}, {'role': 'assistant', 'content': '2 + 2 = **4**'}]
# >  add 4 to that
# > add 4 to that
# 4 + 4 = **8**
# [{'role': 'user', 'content': 'what is 2+2?'}, {'role': 'assistant', 'content': '2 + 2 = **4**'}, {'role': 'user', 'content': 'add 4 to that'}, {'role': 'assistant', 'content': '4 + 4 = **8**'}]
