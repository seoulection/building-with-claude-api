# %%
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages
    )
    return message.content[0].text

# %%
messages = []

# add the initial user question
add_user_message(messages, "Define the taste of durian in one sentence.")

# get claude's response and add it as assistant message
answer = chat(messages)
add_assistant_message(messages, answer)

# follow-up question
add_user_message(messages, "Write another sentence")

final_answer = chat(messages)
final_answer
# Out:
# 'Some people describe it as eating sweet, buttery ice cream in a locker room, capturing the paradox of its deliciously complex flavor and its notorious, overpowering smell.'
